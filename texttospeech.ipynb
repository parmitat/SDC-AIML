# %% [markdown]
# <a href="https://colab.research.google.com/github/HarsikaVetrivel/PYTHONAIML/blob/main/texttospeech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: text to speech code in python

# !pip install gTTS

from gtts import gTTS
from IPython.display import Audio

def text_to_speech(text, language='en'):
  tts = gTTS(text=text, lang=language, slow=False)
  tts.save("speech.mp3")
  return Audio("speech.mp3", autoplay=True)

# Example usage
text_to_speech("Hello, this is a test of text-to-speech.")
# Out:
# ...
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
